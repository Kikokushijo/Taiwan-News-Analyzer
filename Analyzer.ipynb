# %%
from collections import defaultdict, Counter
from functools import reduce
import glob

import pandas as pd
import simplejson as json

# %%
words_filename = 'words/words.csv'

# %%
def wordlist_to_wordset(word_list):
    words = []
    for word_group in word_list:
        if type(word_group) is str:
            words.extend([c.strip() for c in word_group.split('/')])
    return set(words)

def build_tw_cn_dict(tw_word_list, cn_word_list):
    
    tw2cn = defaultdict(list)
    cn2tw = defaultdict(list)
    
    for tw_word_group, cn_word_group in zip(tw_word_list, cn_word_list):
        if type(tw_word_group) is str:
            tw_words = [c.strip() for c in tw_word_group.split('/')]
        else:
            tw_words = [None]
        
        if type(cn_word_group) is str:
            cn_words = [c.strip() for c in cn_word_group.split('/')]
        else:
            tw_words = [None]
            
        for tw_word in tw_words:
            for cn_word in cn_words:
                tw2cn[tw_word].append(cn_word)
                cn2tw[cn_word].append(tw_word)
    
    return tw2cn, cn2tw

def new_defined_wordset(tw_word_list, cn_word_list):
    
    wordset = set()
    for tw_word_group, cn_word_group in zip(tw_word_list, cn_word_list):
        if type(tw_word_group) is str and type(cn_word_group) is str:
            tw_words = [c.strip() for c in tw_word_group.split('/')]
            cn_words = set([c.strip() for c in cn_word_group.split('/')])
            for cn_word in cn_words:
                for tw_word in tw_words:
                    if cn_word in tw_word:
                        break
                else:
                    wordset.add(cn_word)
    
    wordset -= wordlist_to_wordset(tw_word_list)
    return wordset

df = pd.read_csv(words_filename)
cn_word_list = df['cn_word'].tolist()
tw_word_list = df['tw_word'].tolist()
cn_word_set = wordlist_to_wordset(cn_word_list)
tw_word_set = wordlist_to_wordset(tw_word_list)
# filtered_word_set = cn_word_set - tw_word_set
filtered_word_set = new_defined_wordset(tw_word_list, cn_word_list)
tw2cn, cn2tw = build_tw_cn_dict(tw_word_list, cn_word_list)

# %%
def find_cn_words(article, word_set):
    cn_word_count = Counter()
    for cn_word in word_set:
        if cn_word in article:
            cn_word_count[cn_word] += 1
    return cn_word_count

# %%
freq_counter = Counter()
for filename in glob.glob('news/*/*/*'):
    with open(filename, 'r') as f:
        article = json.load(f)
        result = find_cn_words(article['content'], filtered_word_set)
        if result:
            print(article['url'], result)
            freq_counter += result
# Out:
# https://www.setn.com/News.aspx?NewsID=649259 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=649104 Counter({'耳機': 1})
# https://www.setn.com/News.aspx?NewsID=648820 Counter({'診室': 1})
# https://www.setn.com/News.aspx?NewsID=649297 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648765 Counter({'大考': 1})
# https://www.setn.com/News.aspx?NewsID=648751 Counter({'電商': 1, '打的': 1, '調資': 1})
# https://www.setn.com/News.aspx?NewsID=648780 Counter({'診室': 1})
# https://www.setn.com/News.aspx?NewsID=648737 Counter({'大考': 1, '冷食': 1, '花樣': 1, '空客': 1})
# https://www.setn.com/News.aspx?NewsID=648813 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=648773 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=648828 Counter({'現房': 1})
# https://www.setn.com/News.aspx?NewsID=648924 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=649067 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=649239 Counter({'查體': 1})
# https://www.setn.com/News.aspx?NewsID=649041 Counter({'公安局': 1})
# https://www.setn.com/News.aspx?NewsID=649029 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=648832 Counter({'運營': 1, '主頁': 1})
# https://www.setn.com/News.aspx?NewsID=649010 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=644679 Counter({'匝道': 1})
# https://www.setn.com/News.aspx?NewsID=648749 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=648459 Counter({'克隆': 1, '生物技術': 1})
# https://www.setn.com/News.aspx?NewsID=649017 Counter({'網絡': 1})
# https://www.setn.com/News.aspx?NewsID=649319 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=649254 Counter({'筆記本': 1})
# https://www.setn.com/News.aspx?NewsID=648658 Counter({'外帶': 1, '比特': 1})
# https://www.setn.com/News.aspx?NewsID=648992 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648696 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=649288 Counter({'樣條': 1})
# https://www.setn.com/News.aspx?NewsID=649228 Counter({'烏龍指': 1})
# https://www.setn.com/News.aspx?NewsID=649141 Counter({'旅遊車': 1})
# https://www.setn.com/News.aspx?NewsID=648659 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648845 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=648817 Counter({'摩': 1, '電商': 1})
# https://www.setn.com/News.aspx?NewsID=649327 Counter({'大考': 1})
# https://www.setn.com/News.aspx?NewsID=648255 Counter({'死機': 1})
# https://www.setn.com/News.aspx?NewsID=648733 Counter({'診室': 1, '非典': 1})
# https://www.setn.com/News.aspx?NewsID=648767 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=648889 Counter({'網絡': 1})
# https://www.setn.com/News.aspx?NewsID=648810 Counter({'下網': 1})
# https://www.setn.com/News.aspx?NewsID=648736 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=649314 Counter({'保安': 1})
# https://www.setn.com/News.aspx?NewsID=649040 Counter({'志願者': 1, '信息': 1})
# https://www.setn.com/News.aspx?NewsID=649009 Counter({'本體': 1})
# https://www.setn.com/News.aspx?NewsID=649202 Counter({'秋褲': 1})
# https://www.setn.com/News.aspx?NewsID=648975 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=649264 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=648704 Counter({'池塘': 1})
# https://www.setn.com/News.aspx?NewsID=649089 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=649267 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648741 Counter({'大考': 1})
# https://www.setn.com/News.aspx?NewsID=648998 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648690 Counter({'燙頭': 1, '攝像': 1})
# https://www.setn.com/News.aspx?NewsID=648365 Counter({'耳機': 1})
# https://www.setn.com/News.aspx?NewsID=649081 Counter({'施主': 1})
# https://www.setn.com/News.aspx?NewsID=648732 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=648707 Counter({'咖喱': 1})
# https://www.setn.com/News.aspx?NewsID=649103 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=646189 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648661 Counter({'下網': 1})
# https://www.setn.com/News.aspx?NewsID=648895 Counter({'刻錄': 1})
# https://www.setn.com/News.aspx?NewsID=648831 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=648416 Counter({'國家稅': 1})
# https://www.setn.com/News.aspx?NewsID=649075 Counter({'打女': 1})
# https://www.setn.com/News.aspx?NewsID=648665 Counter({'烏龍指': 1})
# https://www.setn.com/News.aspx?NewsID=648842 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=648927 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=649292 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648624 Counter({'道口': 1})
# https://www.setn.com/News.aspx?NewsID=648743 Counter({'摩': 1, '質量': 1})
# https://www.setn.com/News.aspx?NewsID=638983 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=638953 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=639345 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=639188 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=639210 Counter({'水地': 1, '抽水': 1})
# https://www.setn.com/News.aspx?NewsID=639437 Counter({'班車': 1})
# https://www.setn.com/News.aspx?NewsID=639248 Counter({'道口': 1})
# https://www.setn.com/News.aspx?NewsID=639047 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=638967 Counter({'網民': 1, '防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=639102 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=638933 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=639115 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=639527 Counter({'現房': 1})
# https://www.setn.com/News.aspx?NewsID=639399 Counter({'現房': 1})
# https://www.setn.com/News.aspx?NewsID=639515 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=638758 Counter({'網絡': 1, '加車': 1})
# https://www.setn.com/News.aspx?NewsID=639349 Counter({'轉移陣': 1})
# https://www.setn.com/News.aspx?NewsID=639003 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=639475 Counter({'道口': 1})
# https://www.setn.com/News.aspx?NewsID=639016 Counter({'低層': 1})
# https://www.setn.com/News.aspx?NewsID=638801 Counter({'封一': 1})
# https://www.setn.com/News.aspx?NewsID=639483 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=639478 Counter({'沙士': 1})
# https://www.setn.com/News.aspx?NewsID=638164 Counter({'死期': 1})
# https://www.setn.com/News.aspx?NewsID=639446 Counter({'利好': 1})
# https://www.setn.com/News.aspx?NewsID=639395 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=639057 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638796 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=639004 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=639161 Counter({'水劑': 1})
# https://www.setn.com/News.aspx?NewsID=639526 Counter({'噪音污染': 1})
# https://www.setn.com/News.aspx?NewsID=638168 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=639288 Counter({'指揮艦': 1})
# https://www.setn.com/News.aspx?NewsID=638865 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=639158 Counter({'樣本量': 1, '信息': 1})
# https://www.setn.com/News.aspx?NewsID=638763 Counter({'行車': 1, '電動車': 1})
# https://www.setn.com/News.aspx?NewsID=639308 Counter({'耳機': 1})
# https://www.setn.com/News.aspx?NewsID=638985 Counter({'現房': 1})
# https://www.setn.com/News.aspx?NewsID=639403 Counter({'質量': 1})
# https://www.setn.com/News.aspx?NewsID=639177 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=639253 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=639062 Counter({'生物技術': 1})
# https://www.setn.com/News.aspx?NewsID=639025 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=639280 Counter({'保安': 1})
# https://www.setn.com/News.aspx?NewsID=639278 Counter({'國民生產總值': 1})
# https://www.setn.com/News.aspx?NewsID=639145 Counter({'富二代': 1})
# https://www.setn.com/News.aspx?NewsID=638952 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=639128 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=638990 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=639204 Counter({'比特': 1})
# https://www.setn.com/News.aspx?NewsID=638926 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638978 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=639354 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=639259 Counter({'外帶': 1, '行車': 1})
# https://www.setn.com/News.aspx?NewsID=638891 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638991 Counter({'診室': 1})
# https://www.setn.com/News.aspx?NewsID=638689 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=639157 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638511 Counter({'輸液': 1})
# https://www.setn.com/News.aspx?NewsID=639168 Counter({'定點': 1})
# https://www.setn.com/News.aspx?NewsID=639448 Counter({'富二代': 1})
# https://www.setn.com/News.aspx?NewsID=639374 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=639014 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=639316 Counter({'說唱': 1, '摩': 1})
# https://www.setn.com/News.aspx?NewsID=639078 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=639214 Counter({'高清': 1})
# https://www.setn.com/News.aspx?NewsID=639023 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=639305 Counter({'現房': 1})
# https://www.setn.com/News.aspx?NewsID=639452 Counter({'保安': 1, '防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=639117 Counter({'樣本量': 1, '信息': 1})
# https://www.setn.com/News.aspx?NewsID=639499 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=639565 Counter({'外帶': 1, '酸奶': 1})
# https://www.setn.com/News.aspx?NewsID=638986 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=639076 Counter({'大專': 1, '外帶': 1})
# https://www.setn.com/News.aspx?NewsID=639134 Counter({'打女': 1})
# https://www.setn.com/News.aspx?NewsID=639250 Counter({'電商': 1, '行車': 1})
# https://www.setn.com/News.aspx?NewsID=638996 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=639300 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=639554 Counter({'手車': 1})
# https://www.setn.com/News.aspx?NewsID=639220 Counter({'公交': 1})
# https://www.setn.com/News.aspx?NewsID=639173 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=639067 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=639075 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=639466 Counter({'道口': 1})
# https://www.setn.com/News.aspx?NewsID=639407 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=638677 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=639171 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=639084 Counter({'耳機': 1})
# https://www.setn.com/News.aspx?NewsID=639120 Counter({'質量': 1})
# https://www.setn.com/News.aspx?NewsID=639092 Counter({'中介': 1})
# https://www.setn.com/News.aspx?NewsID=639287 Counter({'現房': 1})
# https://www.setn.com/News.aspx?NewsID=636652 Counter({'大考': 1})
# https://www.setn.com/News.aspx?NewsID=637077 Counter({'信息': 1})
# https://www.setn.com/News.aspx?NewsID=636723 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637051 Counter({'網民': 1})
# https://www.setn.com/News.aspx?NewsID=636713 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636908 Counter({'加車': 1})
# https://www.setn.com/News.aspx?NewsID=636637 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636970 Counter({'盜竊案': 1})
# https://www.setn.com/News.aspx?NewsID=637082 Counter({'大考': 1})
# https://www.setn.com/News.aspx?NewsID=636947 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=636698 Counter({'非典': 1})
# https://www.setn.com/News.aspx?NewsID=636853 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=636932 Counter({'保安': 1, '電眼': 1})
# https://www.setn.com/News.aspx?NewsID=636726 Counter({'行車': 1, '網民': 1})
# https://www.setn.com/News.aspx?NewsID=636740 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=637004 Counter({'匝道': 1})
# https://www.setn.com/News.aspx?NewsID=636963 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=636665 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636708 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=636920 Counter({'電商': 1, '數據挖掘': 1, '信息': 1, '信息科技': 1})
# https://www.setn.com/News.aspx?NewsID=636928 Counter({'保安': 1})
# https://www.setn.com/News.aspx?NewsID=636486 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=636800 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637044 Counter({'水劑': 1})
# https://www.setn.com/News.aspx?NewsID=636836 Counter({'行車': 1, '打的': 1})
# https://www.setn.com/News.aspx?NewsID=637025 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=636935 Counter({'摩': 1, '摩爾': 1, '代差': 1})
# https://www.setn.com/News.aspx?NewsID=636819 Counter({'耳機': 1})
# https://www.setn.com/News.aspx?NewsID=636992 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=637085 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637022 Counter({'錄像': 1})
# https://www.setn.com/News.aspx?NewsID=636699 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=637069 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=636638 Counter({'耳機': 1})
# https://www.setn.com/News.aspx?NewsID=635758 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=636878 Counter({'定點': 1})
# https://www.setn.com/News.aspx?NewsID=636754 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=637019 Counter({'友好城市': 1})
# https://www.setn.com/News.aspx?NewsID=636863 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636752 Counter({'站點': 1})
# https://www.setn.com/News.aspx?NewsID=636939 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636737 Counter({'填埋場': 1, '罰款': 1})
# https://www.setn.com/News.aspx?NewsID=636802 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=636687 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636978 Counter({'筆記本': 1})
# https://www.setn.com/News.aspx?NewsID=636799 Counter({'互聯網': 1})
# https://www.setn.com/News.aspx?NewsID=636929 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=636949 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=636833 Counter({'摩': 1, '網關': 1})
# https://www.setn.com/News.aspx?NewsID=636743 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=636785 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=637039 Counter({'定標': 1})
# https://www.setn.com/News.aspx?NewsID=636350 Counter({'富二代': 1})
# https://www.setn.com/News.aspx?NewsID=636791 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=636660 Counter({'診室': 1})
# https://www.setn.com/News.aspx?NewsID=636720 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636718 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=636875 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=636632 Counter({'車帶': 1})
# https://www.setn.com/News.aspx?NewsID=648555 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=648134 Counter({'的士': 1})
# https://www.setn.com/News.aspx?NewsID=648000 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=648304 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648170 Counter({'抽水': 1})
# https://www.setn.com/News.aspx?NewsID=648022 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648471 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648126 Counter({'字符': 1, '薩斯': 1})
# https://www.setn.com/News.aspx?NewsID=648547 Counter({'特行': 1})
# https://www.setn.com/News.aspx?NewsID=648430 Counter({'彈道導彈': 1})
# https://www.setn.com/News.aspx?NewsID=648051 Counter({'定標': 1})
# https://www.setn.com/News.aspx?NewsID=648523 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=647733 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648240 Counter({'質量': 1})
# https://www.setn.com/News.aspx?NewsID=648256 Counter({'網絡': 1})
# https://www.setn.com/News.aspx?NewsID=648456 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=648263 Counter({'網絡': 1})
# https://www.setn.com/News.aspx?NewsID=647587 Counter({'站點': 1})
# https://www.setn.com/News.aspx?NewsID=647842 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=648125 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=648118 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648300 Counter({'電大': 1})
# https://www.setn.com/News.aspx?NewsID=647861 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=648281 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=648115 Counter({'診室': 1})
# https://www.setn.com/News.aspx?NewsID=647849 Counter({'氨基酸': 1})
# https://www.setn.com/News.aspx?NewsID=647795 Counter({'互聯網': 1, '網吧': 1})
# https://www.setn.com/News.aspx?NewsID=647921 Counter({'質量': 1})
# https://www.setn.com/News.aspx?NewsID=648092 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=648095 Counter({'現房': 1})
# https://www.setn.com/News.aspx?NewsID=648149 Counter({'人流': 1})
# https://www.setn.com/News.aspx?NewsID=648054 Counter({'的士': 1, '心理諮詢': 1})
# https://www.setn.com/News.aspx?NewsID=648544 Counter({'門球': 1})
# https://www.setn.com/News.aspx?NewsID=648565 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648558 Counter({'回車': 1})
# https://www.setn.com/News.aspx?NewsID=647541 Counter({'下網': 1})
# https://www.setn.com/News.aspx?NewsID=647973 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=648552 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648519 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=648193 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=648204 Counter({'內帶': 1})
# https://www.setn.com/News.aspx?NewsID=648222 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648452 Counter({'保安': 1})
# https://www.setn.com/News.aspx?NewsID=647981 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=647986 Counter({'網絡': 1})
# https://www.setn.com/News.aspx?NewsID=648360 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648506 Counter({'下網': 1})
# https://www.setn.com/News.aspx?NewsID=648237 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648214 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=648477 Counter({'打印': 1})
# https://www.setn.com/News.aspx?NewsID=647936 Counter({'摩': 1, '電商': 1, '耳機': 1, '博客': 1})
# https://www.setn.com/News.aspx?NewsID=648427 Counter({'大熊貓': 1})
# https://www.setn.com/News.aspx?NewsID=648199 Counter({'班車': 1})
# https://www.setn.com/News.aspx?NewsID=647433 Counter({'友好城市': 1})
# https://www.setn.com/News.aspx?NewsID=648465 Counter({'的士': 1})
# https://www.setn.com/News.aspx?NewsID=648197 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=648311 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=648590 Counter({'定標': 1})
# https://www.setn.com/News.aspx?NewsID=648105 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648060 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=648119 Counter({'首映禮': 1})
# https://www.setn.com/News.aspx?NewsID=647939 Counter({'摩': 1, '打的': 1})
# https://www.setn.com/News.aspx?NewsID=648582 Counter({'烏龍指': 1})
# https://www.setn.com/News.aspx?NewsID=648587 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=647969 Counter({'小時工': 1})
# https://www.setn.com/News.aspx?NewsID=648399 Counter({'保安': 1})
# https://www.setn.com/News.aspx?NewsID=648379 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=647934 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=648210 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648462 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=648550 Counter({'互聯網': 1})
# https://www.setn.com/News.aspx?NewsID=648046 Counter({'人流': 1, '摩': 1})
# https://www.setn.com/News.aspx?NewsID=648220 Counter({'內存': 1})
# https://www.setn.com/News.aspx?NewsID=648594 Counter({'報道': 1})
# https://www.setn.com/News.aspx?NewsID=648472 Counter({'本體': 1, '耳機': 1})
# https://www.setn.com/News.aspx?NewsID=647966 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648289 Counter({'比索': 1})
# https://www.setn.com/News.aspx?NewsID=648211 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=648155 Counter({'小時工': 1})
# https://www.setn.com/News.aspx?NewsID=648154 Counter({'耳機': 1})
# https://www.setn.com/News.aspx?NewsID=648137 Counter({'人流': 1})
# https://www.setn.com/News.aspx?NewsID=648040 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=648499 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=648533 Counter({'博客': 1})
# https://www.setn.com/News.aspx?NewsID=648259 Counter({'網民': 1})
# https://www.setn.com/News.aspx?NewsID=648173 Counter({'外水': 1, '行車': 1})
# https://www.setn.com/News.aspx?NewsID=648339 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=648069 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=648310 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=632463 Counter({'人流': 1, '應用程序': 1})
# https://www.setn.com/News.aspx?NewsID=633467 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=633608 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=633903 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=633712 Counter({'抽水': 1})
# https://www.setn.com/News.aspx?NewsID=633478 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=633531 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=633544 Counter({'摩': 1, '外帶': 1})
# https://www.setn.com/News.aspx?NewsID=633865 Counter({'診室': 1})
# https://www.setn.com/News.aspx?NewsID=633809 Counter({'的士': 1})
# https://www.setn.com/News.aspx?NewsID=633529 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=633846 Counter({'內存': 1})
# https://www.setn.com/News.aspx?NewsID=633717 Counter({'現房': 1})
# https://www.setn.com/News.aspx?NewsID=633847 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=633589 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=633842 Counter({'道口': 1, '防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=633864 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=633490 Counter({'耳機': 1})
# https://www.setn.com/News.aspx?NewsID=632436 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=633840 Counter({'公交': 1})
# https://www.setn.com/News.aspx?NewsID=633451 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=633883 Counter({'摩': 1, '電商': 1})
# https://www.setn.com/News.aspx?NewsID=633465 Counter({'認領': 1, '行車': 1})
# https://www.setn.com/News.aspx?NewsID=633354 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=633442 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=633647 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=633756 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=633664 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=633705 Counter({'人流': 1})
# https://www.setn.com/News.aspx?NewsID=633983 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=633122 Counter({'摩': 1, '電動車': 1})
# https://www.setn.com/News.aspx?NewsID=633509 Counter({'耳機': 1})
# https://www.setn.com/News.aspx?NewsID=633551 Counter({'移動通信': 1})
# https://www.setn.com/News.aspx?NewsID=633457 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=633305 Counter({'沙包': 1})
# https://www.setn.com/News.aspx?NewsID=633448 Counter({'摩': 1, '電商': 1, '外帶': 1})
# https://www.setn.com/News.aspx?NewsID=633562 Counter({'釉質': 1})
# https://www.setn.com/News.aspx?NewsID=633443 Counter({'盜竊案': 1})
# https://www.setn.com/News.aspx?NewsID=633094 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=633920 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=633493 Counter({'網民': 1})
# https://www.setn.com/News.aspx?NewsID=633893 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=633648 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=633507 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=633772 Counter({'保安': 1})
# https://www.setn.com/News.aspx?NewsID=633894 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=633703 Counter({'摩': 1, '電商': 1})
# https://www.setn.com/News.aspx?NewsID=633640 Counter({'匝道': 1})
# https://www.setn.com/News.aspx?NewsID=633672 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=633446 Counter({'阿飛': 1})
# https://www.setn.com/News.aspx?NewsID=633416 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=634007 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=633658 Counter({'定點': 1})
# https://www.setn.com/News.aspx?NewsID=633731 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=633727 Counter({'人流': 1})
# https://www.setn.com/News.aspx?NewsID=633939 Counter({'公交': 1})
# https://www.setn.com/News.aspx?NewsID=633549 Counter({'非典': 1})
# https://www.setn.com/News.aspx?NewsID=633458 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=633950 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=633711 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=633322 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=633723 Counter({'摩': 1, '電商': 1})
# https://www.setn.com/News.aspx?NewsID=633929 Counter({'髮卡': 1})
# https://www.setn.com/News.aspx?NewsID=633665 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=634168 Counter({'摩': 1, '電商': 1})
# https://www.setn.com/News.aspx?NewsID=633595 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=633795 Counter({'輔道': 1, '防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=633474 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=633762 Counter({'中介': 1})
# https://www.setn.com/News.aspx?NewsID=633984 Counter({'施主': 1})
# https://www.setn.com/News.aspx?NewsID=633606 Counter({'道口': 1, '防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=633733 Counter({'空客': 1})
# https://www.setn.com/News.aspx?NewsID=633833 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=633870 Counter({'懸念': 1})
# https://www.setn.com/News.aspx?NewsID=633896 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=633599 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=633907 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=633957 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=633690 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=633277 Counter({'收容所': 1})
# https://www.setn.com/News.aspx?NewsID=633612 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=634011 Counter({'打女': 1})
# https://www.setn.com/News.aspx?NewsID=633797 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=633729 Counter({'耳機': 1})
# https://www.setn.com/News.aspx?NewsID=633470 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=633653 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=632977 Counter({'電商': 1, '外帶': 1})
# https://www.setn.com/News.aspx?NewsID=633575 Counter({'道口': 1})
# https://www.setn.com/News.aspx?NewsID=633447 Counter({'摩': 1, '電商': 1, '博客': 1})
# https://www.setn.com/News.aspx?NewsID=633657 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=633454 Counter({'回車': 1, '摩': 1})
# https://www.setn.com/News.aspx?NewsID=637448 Counter({'摩': 1, '保安': 1})
# https://www.setn.com/News.aspx?NewsID=637614 Counter({'沙包': 1})
# https://www.setn.com/News.aspx?NewsID=637919 Counter({'的士': 1})
# https://www.setn.com/News.aspx?NewsID=637640 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=637877 Counter({'利好': 1})
# https://www.setn.com/News.aspx?NewsID=637895 Counter({'乾花': 1})
# https://www.setn.com/News.aspx?NewsID=637505 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=632700 Counter({'摩': 1, '電動車': 1, '奔馳': 1})
# https://www.setn.com/News.aspx?NewsID=637973 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637636 Counter({'內存': 1})
# https://www.setn.com/News.aspx?NewsID=638048 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=637800 Counter({'水培': 1})
# https://www.setn.com/News.aspx?NewsID=637734 Counter({'懸念': 1})
# https://www.setn.com/News.aspx?NewsID=637961 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=637872 Counter({'本體': 1})
# https://www.setn.com/News.aspx?NewsID=637637 Counter({'腦死亡': 1})
# https://www.setn.com/News.aspx?NewsID=637764 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=637790 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=637874 Counter({'診室': 1})
# https://www.setn.com/News.aspx?NewsID=637703 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637820 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=637617 Counter({'摩': 1, '打的': 1})
# https://www.setn.com/News.aspx?NewsID=637989 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638065 Counter({'危害公共安全罪': 1, '最高人民法院': 1})
# https://www.setn.com/News.aspx?NewsID=637802 Counter({'攝像': 1})
# https://www.setn.com/News.aspx?NewsID=638134 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=637641 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=637858 Counter({'車帶': 1, '身份證': 1})
# https://www.setn.com/News.aspx?NewsID=637813 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=637953 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=637769 Counter({'波普': 1})
# https://www.setn.com/News.aspx?NewsID=637782 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637842 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=637933 Counter({'定標': 1})
# https://www.setn.com/News.aspx?NewsID=637665 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=638189 Counter({'網絡': 1})
# https://www.setn.com/News.aspx?NewsID=637685 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=638000 Counter({'本體': 1})
# https://www.setn.com/News.aspx?NewsID=637702 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=638087 Counter({'診室': 1})
# https://www.setn.com/News.aspx?NewsID=636775 Counter({'電眼': 1})
# https://www.setn.com/News.aspx?NewsID=637151 Counter({'吉士': 1})
# https://www.setn.com/News.aspx?NewsID=637992 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=638097 Counter({'打女': 1})
# https://www.setn.com/News.aspx?NewsID=638095 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=637867 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638022 Counter({'爆震彈': 1})
# https://www.setn.com/News.aspx?NewsID=637739 Counter({'接手': 1, '公安局': 1})
# https://www.setn.com/News.aspx?NewsID=636905 Counter({'抽水': 1})
# https://www.setn.com/News.aspx?NewsID=638170 Counter({'摩': 1, '富二代': 1})
# https://www.setn.com/News.aspx?NewsID=636941 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637662 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637645 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=637673 Counter({'摩': 1, '娛樂城': 1})
# https://www.setn.com/News.aspx?NewsID=637825 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638167 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=637783 Counter({'低層': 1})
# https://www.setn.com/News.aspx?NewsID=637634 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637796 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=637629 Counter({'身份證': 1})
# https://www.setn.com/News.aspx?NewsID=637929 Counter({'摩': 1, '電商': 1})
# https://www.setn.com/News.aspx?NewsID=637930 Counter({'中介': 1})
# https://www.setn.com/News.aspx?NewsID=637761 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=638112 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637280 Counter({'大考': 1})
# https://www.setn.com/News.aspx?NewsID=637830 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=637700 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=637844 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=637704 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=637823 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=638161 Counter({'罰款': 1, '極差': 1})
# https://www.setn.com/News.aspx?NewsID=637918 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=638001 Counter({'刑偵': 1, '防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=637905 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=637995 Counter({'診室': 1})
# https://www.setn.com/News.aspx?NewsID=637756 Counter({'國際奧委會': 1})
# https://www.setn.com/News.aspx?NewsID=637976 Counter({'咖喱': 1})
# https://www.setn.com/News.aspx?NewsID=636911 Counter({'逆反心理': 1, '逆反': 1})
# https://www.setn.com/News.aspx?NewsID=638052 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=637720 Counter({'水地': 1})
# https://www.setn.com/News.aspx?NewsID=637124 Counter({'摩': 1, '診室': 1})
# https://www.setn.com/News.aspx?NewsID=637822 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=638187 Counter({'質檢': 1})
# https://www.setn.com/News.aspx?NewsID=637693 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=637749 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=637780 Counter({'暖風機': 1})
# https://www.setn.com/News.aspx?NewsID=638014 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=638176 Counter({'首付': 1})
# https://www.setn.com/News.aspx?NewsID=637616 Counter({'打車': 1, '定點': 1})
# https://www.setn.com/News.aspx?NewsID=637990 Counter({'現房': 1})
# https://www.setn.com/News.aspx?NewsID=636915 Counter({'代母': 1})
# https://www.setn.com/News.aspx?NewsID=637789 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637368 Counter({'手車': 1})
# https://www.setn.com/News.aspx?NewsID=637689 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=638042 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=637810 Counter({'內存': 1})
# https://www.setn.com/News.aspx?NewsID=638086 Counter({'網民': 1})
# https://www.setn.com/News.aspx?NewsID=637651 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=637639 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637903 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636006 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=637836 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637618 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637744 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637882 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637978 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=637926 Counter({'超支': 1})
# https://www.setn.com/News.aspx?NewsID=637714 Counter({'耳機': 1})
# https://www.setn.com/News.aspx?NewsID=635113 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=634767 Counter({'水地': 1})
# https://www.setn.com/News.aspx?NewsID=635233 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=635214 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=634972 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=634552 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=634844 Counter({'電大': 1})
# https://www.setn.com/News.aspx?NewsID=634764 Counter({'診室': 1})
# https://www.setn.com/News.aspx?NewsID=635324 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=634696 Counter({'拔海': 1})
# https://www.setn.com/News.aspx?NewsID=634744 Counter({'大專': 1, '防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=635331 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=634740 Counter({'蔻蔻': 1})
# https://www.setn.com/News.aspx?NewsID=634579 Counter({'質量': 1})
# https://www.setn.com/News.aspx?NewsID=634784 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=634697 Counter({'低層': 1})
# https://www.setn.com/News.aspx?NewsID=635210 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=634715 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=634781 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=634907 Counter({'調資': 1})
# https://www.setn.com/News.aspx?NewsID=635262 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=635054 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=634808 Counter({'富二代': 1})
# https://www.setn.com/News.aspx?NewsID=634805 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=634538 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=634686 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=634721 Counter({'道口': 1})
# https://www.setn.com/News.aspx?NewsID=635230 Counter({'拔海': 1, '電商': 1})
# https://www.setn.com/News.aspx?NewsID=635254 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=635689 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=634770 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=634918 Counter({'接手': 1, '冷食': 1})
# https://www.setn.com/News.aspx?NewsID=635161 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=634506 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=635252 Counter({'手車': 1})
# https://www.setn.com/News.aspx?NewsID=635001 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=635247 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=634969 Counter({'運營': 1})
# https://www.setn.com/News.aspx?NewsID=634669 Counter({'電動車': 1, '奔馳': 1})
# https://www.setn.com/News.aspx?NewsID=634713 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=634903 Counter({'網民': 1})
# https://www.setn.com/News.aspx?NewsID=634771 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=635185 Counter({'輪帶': 1})
# https://www.setn.com/News.aspx?NewsID=634689 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=634687 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=635175 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=635253 Counter({'網絡': 1, '互聯網': 1})
# https://www.setn.com/News.aspx?NewsID=635323 Counter({'大考': 1})
# https://www.setn.com/News.aspx?NewsID=635097 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=635147 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=634979 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=635012 Counter({'收容所': 1})
# https://www.setn.com/News.aspx?NewsID=634790 Counter({'富二代': 1})
# https://www.setn.com/News.aspx?NewsID=635320 Counter({'保安': 1})
# https://www.setn.com/News.aspx?NewsID=634787 Counter({'質量': 1})
# https://www.setn.com/News.aspx?NewsID=635314 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=635279 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=634688 Counter({'免提': 1})
# https://www.setn.com/News.aspx?NewsID=635159 Counter({'震級': 1})
# https://www.setn.com/News.aspx?NewsID=634852 Counter({'現房': 1})
# https://www.setn.com/News.aspx?NewsID=635014 Counter({'登機口': 1})
# https://www.setn.com/News.aspx?NewsID=634783 Counter({'網民': 1})
# https://www.setn.com/News.aspx?NewsID=635300 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=634709 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=635169 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=634702 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=635002 Counter({'本體': 1})
# https://www.setn.com/News.aspx?NewsID=634797 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=634828 Counter({'行車': 1, '電動車': 1})
# https://www.setn.com/News.aspx?NewsID=634719 Counter({'道口': 1})
# https://www.setn.com/News.aspx?NewsID=634498 Counter({'大考': 1})
# https://www.setn.com/News.aspx?NewsID=634900 Counter({'本體': 1})
# https://www.setn.com/News.aspx?NewsID=635266 Counter({'薩斯': 1})
# https://www.setn.com/News.aspx?NewsID=635118 Counter({'保安': 1})
# https://www.setn.com/News.aspx?NewsID=635184 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=635071 Counter({'主頁': 1})
# https://www.setn.com/News.aspx?NewsID=634692 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=635079 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=634857 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=634681 Counter({'籃筐': 1})
# https://www.setn.com/News.aspx?NewsID=635282 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=634729 Counter({'拔海': 1})
# https://www.setn.com/News.aspx?NewsID=634876 Counter({'運營': 1})
# https://www.setn.com/News.aspx?NewsID=634978 Counter({'信息': 1})
# https://www.setn.com/News.aspx?NewsID=634960 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=634865 Counter({'互聯網': 1})
# https://www.setn.com/News.aspx?NewsID=634799 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=634864 Counter({'超支': 1})
# https://www.setn.com/News.aspx?NewsID=650887 Counter({'花樣': 1})
# https://www.setn.com/News.aspx?NewsID=637277 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=637376 Counter({'富二代': 1})
# https://www.setn.com/News.aspx?NewsID=637162 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=637253 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=634880 Counter({'富二代': 1})
# https://www.setn.com/News.aspx?NewsID=637184 Counter({'保安': 1, '打的': 1})
# https://www.setn.com/News.aspx?NewsID=637603 Counter({'的士': 1})
# https://www.setn.com/News.aspx?NewsID=634869 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=637467 Counter({'網絡': 1})
# https://www.setn.com/News.aspx?NewsID=637262 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=637276 Counter({'本體': 1})
# https://www.setn.com/News.aspx?NewsID=637471 Counter({'打女': 1})
# https://www.setn.com/News.aspx?NewsID=637348 Counter({'超支': 1})
# https://www.setn.com/News.aspx?NewsID=637230 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=637252 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637261 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=637282 Counter({'超支': 1, '摩': 1})
# https://www.setn.com/News.aspx?NewsID=637323 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=637209 Counter({'封一': 1})
# https://www.setn.com/News.aspx?NewsID=637503 Counter({'非典': 1})
# https://www.setn.com/News.aspx?NewsID=637221 Counter({'牽頭': 1})
# https://www.setn.com/News.aspx?NewsID=637593 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637347 Counter({'神經症': 1})
# https://www.setn.com/News.aspx?NewsID=637381 Counter({'志願者': 1})
# https://www.setn.com/News.aspx?NewsID=637413 Counter({'人流': 1})
# https://www.setn.com/News.aspx?NewsID=637406 Counter({'基因組': 1, '分辨率': 1})
# https://www.setn.com/News.aspx?NewsID=637199 Counter({'質量': 1})
# https://www.setn.com/News.aspx?NewsID=637464 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=637532 Counter({'打女': 1})
# https://www.setn.com/News.aspx?NewsID=637457 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637539 Counter({'套服': 1})
# https://www.setn.com/News.aspx?NewsID=637241 Counter({'摩': 1, '考機': 1})
# https://www.setn.com/News.aspx?NewsID=637214 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637502 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=637130 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=637558 Counter({'打女': 1})
# https://www.setn.com/News.aspx?NewsID=637322 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=637190 Counter({'診室': 1})
# https://www.setn.com/News.aspx?NewsID=637573 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=637591 Counter({'套服': 1})
# https://www.setn.com/News.aspx?NewsID=637555 Counter({'扁桃體': 1})
# https://www.setn.com/News.aspx?NewsID=637388 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=637434 Counter({'診室': 1})
# https://www.setn.com/News.aspx?NewsID=637094 Counter({'車帶': 1, '液化氣': 1})
# https://www.setn.com/News.aspx?NewsID=636916 Counter({'格里曆': 1})
# https://www.setn.com/News.aspx?NewsID=637589 Counter({'菜譜': 1})
# https://www.setn.com/News.aspx?NewsID=637163 Counter({'摩': 1, '打車': 1})
# https://www.setn.com/News.aspx?NewsID=637243 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=637170 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636303 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=637344 Counter({'大考': 1})
# https://www.setn.com/News.aspx?NewsID=637542 Counter({'定標': 1})
# https://www.setn.com/News.aspx?NewsID=637301 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637281 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637363 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=637195 Counter({'摩': 1, '坎': 1})
# https://www.setn.com/News.aspx?NewsID=637416 Counter({'摩': 1, '比索': 1})
# https://www.setn.com/News.aspx?NewsID=637456 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=637594 Counter({'信息': 1})
# https://www.setn.com/News.aspx?NewsID=637167 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=637382 Counter({'的士': 1})
# https://www.setn.com/News.aspx?NewsID=637257 Counter({'人流': 1})
# https://www.setn.com/News.aspx?NewsID=637265 Counter({'恐高': 1})
# https://www.setn.com/News.aspx?NewsID=637353 Counter({'網絡': 1})
# https://www.setn.com/News.aspx?NewsID=637316 Counter({'水地': 1})
# https://www.setn.com/News.aspx?NewsID=637205 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=637307 Counter({'人流': 1})
# https://www.setn.com/News.aspx?NewsID=637225 Counter({'早教': 1})
# https://www.setn.com/News.aspx?NewsID=636467 Counter({'中介': 1})
# https://www.setn.com/News.aspx?NewsID=637453 Counter({'奔馳': 1})
# https://www.setn.com/News.aspx?NewsID=637186 Counter({'網絡': 1})
# https://www.setn.com/News.aspx?NewsID=637224 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=637272 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=637235 Counter({'高清': 1})
# https://www.setn.com/News.aspx?NewsID=637564 Counter({'信息': 1})
# https://www.setn.com/News.aspx?NewsID=634962 Counter({'電商': 1, '行車': 1})
# https://www.setn.com/News.aspx?NewsID=636193 Counter({'車帶': 1})
# https://www.setn.com/News.aspx?NewsID=636387 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=636090 Counter({'質量': 1})
# https://www.setn.com/News.aspx?NewsID=636206 Counter({'高清': 1})
# https://www.setn.com/News.aspx?NewsID=636495 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636398 Counter({'代母': 1, '摩': 1})
# https://www.setn.com/News.aspx?NewsID=636061 Counter({'信息': 1})
# https://www.setn.com/News.aspx?NewsID=636441 Counter({'水地': 1})
# https://www.setn.com/News.aspx?NewsID=636113 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=636265 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=636358 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=636373 Counter({'心理諮詢': 1})
# https://www.setn.com/News.aspx?NewsID=636141 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=636630 Counter({'牽頭': 1})
# https://www.setn.com/News.aspx?NewsID=636418 Counter({'筆記本': 1})
# https://www.setn.com/News.aspx?NewsID=636399 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=636260 Counter({'奔馳': 1})
# https://www.setn.com/News.aspx?NewsID=636414 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=636165 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=636566 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=636404 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636011 Counter({'公安局': 1})
# https://www.setn.com/News.aspx?NewsID=636074 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=636056 Counter({'診室': 1})
# https://www.setn.com/News.aspx?NewsID=636120 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=636595 Counter({'抽水': 1})
# https://www.setn.com/News.aspx?NewsID=636397 Counter({'收容所': 1})
# https://www.setn.com/News.aspx?NewsID=635994 Counter({'信息': 1})
# https://www.setn.com/News.aspx?NewsID=633724 Counter({'的士': 1})
# https://www.setn.com/News.aspx?NewsID=636375 Counter({'花樣': 1})
# https://www.setn.com/News.aspx?NewsID=636444 Counter({'低層': 1})
# https://www.setn.com/News.aspx?NewsID=636008 Counter({'摩': 1, '認領': 1})
# https://www.setn.com/News.aspx?NewsID=636035 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=636127 Counter({'病疫': 1})
# https://www.setn.com/News.aspx?NewsID=636280 Counter({'信息': 1, '信息科技': 1})
# https://www.setn.com/News.aspx?NewsID=636176 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=636500 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636054 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=636626 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636087 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=636031 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=636489 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636111 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=636483 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=636428 Counter({'步行街': 1})
# https://www.setn.com/News.aspx?NewsID=635449 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=635855 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=636513 Counter({'回車': 1})
# https://www.setn.com/News.aspx?NewsID=636468 Counter({'身份證': 1})
# https://www.setn.com/News.aspx?NewsID=636328 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=636034 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636589 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=636438 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=636378 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=636472 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636230 Counter({'耳機': 1})
# https://www.setn.com/News.aspx?NewsID=636125 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636160 Counter({'摩': 1, '定標': 1})
# https://www.setn.com/News.aspx?NewsID=636601 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636534 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636376 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=636119 Counter({'高清': 1})
# https://www.setn.com/News.aspx?NewsID=636110 Counter({'接手': 1, '行車': 1, '電大': 1, '電動車': 1})
# ...
# https://www.setn.com/News.aspx?NewsID=643994 Counter({'定點': 1})
# https://www.setn.com/News.aspx?NewsID=643853 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=643906 Counter({'筆記本': 1})
# https://www.setn.com/News.aspx?NewsID=644148 Counter({'恐高': 1})
# https://www.setn.com/News.aspx?NewsID=643895 Counter({'網絡': 1})
# https://www.setn.com/News.aspx?NewsID=632413 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=631928 Counter({'摩': 1, '電商': 1, '外帶': 1})
# https://www.setn.com/News.aspx?NewsID=632404 Counter({'保安': 1})
# https://www.setn.com/News.aspx?NewsID=632388 Counter({'公安局': 1})
# https://www.setn.com/News.aspx?NewsID=631993 Counter({'施主': 1})
# https://www.setn.com/News.aspx?NewsID=631983 Counter({'電商': 1, '雲計算': 1})
# https://www.setn.com/News.aspx?NewsID=631764 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=632373 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=631978 Counter({'保安': 1})
# https://www.setn.com/News.aspx?NewsID=632129 Counter({'網絡': 1})
# https://www.setn.com/News.aspx?NewsID=632222 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=631945 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=631973 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=632100 Counter({'錄像': 1, '防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=632485 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=632375 Counter({'網絡': 1})
# https://www.setn.com/News.aspx?NewsID=632021 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=632060 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=632123 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=632245 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=632342 Counter({'套服': 1})
# https://www.setn.com/News.aspx?NewsID=632520 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=631940 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=632071 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=632075 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=632511 Counter({'亞行': 1})
# https://www.setn.com/News.aspx?NewsID=632079 Counter({'網絡': 1})
# https://www.setn.com/News.aspx?NewsID=632095 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=632477 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=632018 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=632280 Counter({'彩點': 1})
# https://www.setn.com/News.aspx?NewsID=632191 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=632029 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=631982 Counter({'奔馳': 1})
# https://www.setn.com/News.aspx?NewsID=632431 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=632475 Counter({'摩': 1, '現房': 1})
# https://www.setn.com/News.aspx?NewsID=632341 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=632124 Counter({'空客': 1})
# https://www.setn.com/News.aspx?NewsID=632031 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=632145 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=632369 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=632479 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=632087 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=632232 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=632057 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=632065 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=632496 Counter({'震中': 1})
# https://www.setn.com/News.aspx?NewsID=632234 Counter({'電眼': 1})
# https://www.setn.com/News.aspx?NewsID=632419 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=632040 Counter({'筆記本': 1})
# https://www.setn.com/News.aspx?NewsID=632350 Counter({'懸念': 1})
# https://www.setn.com/News.aspx?NewsID=631963 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=632470 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=631975 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=632108 Counter({'輪帶': 1})
# https://www.setn.com/News.aspx?NewsID=632307 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=632088 Counter({'摩': 1, '摩爾': 1})
# https://www.setn.com/News.aspx?NewsID=632279 Counter({'大考': 1})
# https://www.setn.com/News.aspx?NewsID=632244 Counter({'摩': 1, '電商': 1})
# https://www.setn.com/News.aspx?NewsID=632152 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=632090 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=631952 Counter({'震中': 1})
# https://www.setn.com/News.aspx?NewsID=632374 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=631611 Counter({'盒帶': 1})
# https://www.setn.com/News.aspx?NewsID=631918 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=632396 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=632178 Counter({'電商': 1, '運營': 1})
# https://www.setn.com/News.aspx?NewsID=632207 Counter({'中介': 1})
# https://www.setn.com/News.aspx?NewsID=631970 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=632526 Counter({'電商': 1, '耳機': 1})
# https://www.setn.com/News.aspx?NewsID=631988 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=632498 Counter({'內存': 1})
# https://www.setn.com/News.aspx?NewsID=632236 Counter({'電大': 1})
# https://www.setn.com/News.aspx?NewsID=631250 Counter({'筆記本': 1})
# https://www.setn.com/News.aspx?NewsID=631207 Counter({'下網': 1})
# https://www.setn.com/News.aspx?NewsID=631254 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=631247 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=631216 Counter({'網絡': 1})
# https://www.setn.com/News.aspx?NewsID=638857 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638912 Counter({'套服': 1})
# https://www.setn.com/News.aspx?NewsID=638319 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=638411 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638684 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=638021 Counter({'內存': 1})
# https://www.setn.com/News.aspx?NewsID=638525 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=638678 Counter({'水地': 1})
# https://www.setn.com/News.aspx?NewsID=638541 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=638736 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=638213 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638921 Counter({'短信': 1})
# https://www.setn.com/News.aspx?NewsID=638208 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=638451 Counter({'期房': 1})
# https://www.setn.com/News.aspx?NewsID=638335 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638386 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=638606 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=638224 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638355 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=638628 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=638851 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=638380 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=638236 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=638424 Counter({'同傳': 1})
# https://www.setn.com/News.aspx?NewsID=638246 Counter({'信息': 1})
# https://www.setn.com/News.aspx?NewsID=638895 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638593 Counter({'保安': 1})
# https://www.setn.com/News.aspx?NewsID=638266 Counter({'字節': 1})
# https://www.setn.com/News.aspx?NewsID=638923 Counter({'定點': 1})
# https://www.setn.com/News.aspx?NewsID=638638 Counter({'診室': 1})
# https://www.setn.com/News.aspx?NewsID=638278 Counter({'發達國家': 1})
# https://www.setn.com/News.aspx?NewsID=638632 Counter({'恐高': 1})
# https://www.setn.com/News.aspx?NewsID=638225 Counter({'診室': 1})
# https://www.setn.com/News.aspx?NewsID=638256 Counter({'保安': 1})
# https://www.setn.com/News.aspx?NewsID=638566 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=638404 Counter({'咖喱': 1})
# https://www.setn.com/News.aspx?NewsID=638423 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=638594 Counter({'超支': 1, '摩': 1})
# https://www.setn.com/News.aspx?NewsID=638427 Counter({'標底': 1})
# https://www.setn.com/News.aspx?NewsID=638476 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=638243 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638433 Counter({'摩': 1, '接手': 1})
# https://www.setn.com/News.aspx?NewsID=638786 Counter({'筆記本': 1})
# https://www.setn.com/News.aspx?NewsID=638196 Counter({'比特': 1})
# https://www.setn.com/News.aspx?NewsID=638306 Counter({'社交網站': 1})
# https://www.setn.com/News.aspx?NewsID=638595 Counter({'質量': 1})
# https://www.setn.com/News.aspx?NewsID=638381 Counter({'沙包': 1})
# https://www.setn.com/News.aspx?NewsID=638501 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=638589 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=638523 Counter({'道口': 1, '大專': 1})
# https://www.setn.com/News.aspx?NewsID=638480 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=638767 Counter({'打女': 1})
# https://www.setn.com/News.aspx?NewsID=638370 Counter({'人流': 1})
# https://www.setn.com/News.aspx?NewsID=638742 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=638407 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=638234 Counter({'耳機': 1})
# https://www.setn.com/News.aspx?NewsID=638401 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638590 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638349 Counter({'下網': 1})
# https://www.setn.com/News.aspx?NewsID=638793 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638660 Counter({'東盟': 1})
# https://www.setn.com/News.aspx?NewsID=638568 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=638455 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638780 Counter({'藝術體操': 1})
# https://www.setn.com/News.aspx?NewsID=638485 Counter({'電眼': 1})
# https://www.setn.com/News.aspx?NewsID=638282 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=638264 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638313 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=638802 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=638652 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=638409 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=638312 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=638619 Counter({'質檢': 1, '定點': 1})
# https://www.setn.com/News.aspx?NewsID=638218 Counter({'低層': 1})
# https://www.setn.com/News.aspx?NewsID=638453 Counter({'大考': 1})
# https://www.setn.com/News.aspx?NewsID=638545 Counter({'富二代': 1})
# https://www.setn.com/News.aspx?NewsID=638719 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638275 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=636223 Counter({'道口': 1, '行車': 1})
# https://www.setn.com/News.aspx?NewsID=638459 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=638737 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=638700 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=638384 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=638845 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=638564 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=640885 Counter({'認領': 1})
# https://www.setn.com/News.aspx?NewsID=640363 Counter({'刷屏': 1})
# https://www.setn.com/News.aspx?NewsID=640484 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=640344 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=640328 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640725 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=640694 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640653 Counter({'保安': 1, '行車': 1})
# https://www.setn.com/News.aspx?NewsID=640546 Counter({'下網': 1})
# https://www.setn.com/News.aspx?NewsID=640562 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=640807 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=640149 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=640796 Counter({'滿勤': 1})
# https://www.setn.com/News.aspx?NewsID=640468 Counter({'超支': 1})
# https://www.setn.com/News.aspx?NewsID=640402 Counter({'薩斯': 1})
# https://www.setn.com/News.aspx?NewsID=636070 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=640703 Counter({'富二代': 1})
# https://www.setn.com/News.aspx?NewsID=640337 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640255 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640846 Counter({'奔馳': 1})
# https://www.setn.com/News.aspx?NewsID=640352 Counter({'花樣': 1, '激光': 1})
# https://www.setn.com/News.aspx?NewsID=640761 Counter({'高清': 1})
# https://www.setn.com/News.aspx?NewsID=640316 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=640520 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640518 Counter({'接手': 1})
# https://www.setn.com/News.aspx?NewsID=640625 Counter({'高清': 1})
# https://www.setn.com/News.aspx?NewsID=640680 Counter({'套服': 1})
# https://www.setn.com/News.aspx?NewsID=640366 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=640738 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640368 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640852 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640350 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640451 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=639968 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640365 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=640425 Counter({'人流': 1})
# https://www.setn.com/News.aspx?NewsID=640389 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640892 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640341 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=640750 Counter({'打的': 1})
# https://www.setn.com/News.aspx?NewsID=640374 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=640378 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640851 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640876 Counter({'水地': 1})
# https://www.setn.com/News.aspx?NewsID=640415 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640429 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=640675 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=640727 Counter({'保安': 1})
# https://www.setn.com/News.aspx?NewsID=640386 Counter({'保安': 1})
# https://www.setn.com/News.aspx?NewsID=640877 Counter({'認領': 1})
# https://www.setn.com/News.aspx?NewsID=640706 Counter({'發展中國家': 1})
# https://www.setn.com/News.aspx?NewsID=640364 Counter({'下網': 1})
# https://www.setn.com/News.aspx?NewsID=640678 Counter({'池塘': 1})
# https://www.setn.com/News.aspx?NewsID=640486 Counter({'中介': 1})
# https://www.setn.com/News.aspx?NewsID=635999 Counter({'保安': 1})
# https://www.setn.com/News.aspx?NewsID=640858 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640303 Counter({'婚房': 1})
# https://www.setn.com/News.aspx?NewsID=640572 Counter({'運營': 1})
# https://www.setn.com/News.aspx?NewsID=640765 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640379 Counter({'罰款': 1})
# https://www.setn.com/News.aspx?NewsID=640293 Counter({'桑巴': 1})
# https://www.setn.com/News.aspx?NewsID=640630 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=640467 Counter({'電動車': 1})
# https://www.setn.com/News.aspx?NewsID=640342 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=639116 Counter({'防暴警察': 1})
# https://www.setn.com/News.aspx?NewsID=640083 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640646 Counter({'抽水': 1})
# https://www.setn.com/News.aspx?NewsID=640814 Counter({'質量': 1})
# https://www.setn.com/News.aspx?NewsID=640689 Counter({'大專': 1})
# https://www.setn.com/News.aspx?NewsID=640299 Counter({'公安局': 1})
# https://www.setn.com/News.aspx?NewsID=640465 Counter({'外帶': 1})
# https://www.setn.com/News.aspx?NewsID=640744 Counter({'坎': 1})
# https://www.setn.com/News.aspx?NewsID=640640 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=639297 Counter({'摩': 1})
# https://www.setn.com/News.aspx?NewsID=640409 Counter({'質量': 1})
# https://www.setn.com/News.aspx?NewsID=640574 Counter({'電商': 1})
# https://www.setn.com/News.aspx?NewsID=640548 Counter({'比特': 1})
# https://www.setn.com/News.aspx?NewsID=640695 Counter({'保安': 1})
# https://www.setn.com/News.aspx?NewsID=640539 Counter({'行車': 1})
# https://www.setn.com/News.aspx?NewsID=640662 Counter({'坎': 1})
